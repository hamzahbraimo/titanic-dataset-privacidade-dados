# %%
import pandas as pd

# %%
df_dirty = pd.read_csv('../data/titanic.csv')

df_dirty.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df_cl = pd.read_csv('../data/titanic_clean.csv')

df_cl.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex  Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male   22      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# ...

# %%
df_tratado = pd.read_csv('../data/titanic_tratado.csv')

df_tratado.head(20)
# Out:
#    PassengerId  Survived Pclass  \
# 0     b2c01aa6         0   ae6a
# 1     40d6a98a         1   8228
# 2     34658ad9         1   ae6a
# 3     c341f6a5         1   8228
# 4     fe4733a9         0   ae6a
# 5     a91b656c         0   ae6a
# 6     3cd8d40e         0   8228
# 7     59227a7f         0   ae6a
# 8     b3ebeee0         1   ae6a
# 9     7e85c3d3         1   300d
# 10    b8c7922a         1   ae6a
# 11    1631c9c8         1   8228
# 12    412e1779         0   ae6a
# 13    9927dd52         0   ae6a
# 14    49e21327         0   ae6a
# 15    f4edbe98         1   300d
# 16    02828e72         0   ae6a
# 17    9a2b0136         1   300d
# 18    51f33e4f         0   ae6a
# 19    bb9e4779         1   ae6a
#
#                                                  Name     Age    NrFamiliares  \
# 0   6c969dc7ad8ff99ae4959829c664e8537f5f98a23f41c1...  Adulto         Pequena
# 1   f7ad2d69edefb38cae0679b6e6a8953b3f5892c9d12a57...  Adulto         Pequena
# ...
